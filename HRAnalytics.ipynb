# %%
import pandas as pd
import numpy as np
from pprint import pprint

 
hr_data = pd.read_csv(r"C:\Users\Alamelu Lakshmanan\Desktop\classificationhr.csv")
hr_data.head()
# Out:
#    Age Attrition    Business Travel  Daily rate              Department  \
# 0   41       Yes      Travel_Rarely        1102                   Sales
# 1   49        No  Travel_Frequently         279  Research & Development
# 2   37       Yes      Travel_Rarely        1373  Research & Development
# 3   33        No  Travel_Frequently        1392  Research & Development
# 4   27        No      Travel_Rarely         591  Research & Development
#
#    Distance from home  Education Education field  Employee count  \
# 0                   1          2   Life Sciences               1
# 1                   8          1   Life Sciences               1
# 2                   2          2           Other               1
# 3                   3          4   Life Sciences               1
# 4                   2          1         Medical               1
#
#    Employee number  ...  Relationship satisfaction Standard hours  \
# 0                1  ...                          1             80
# ...

# %%
hr_data.isnull().sum()
# Out:
# Age                           0
# Attrition                     0
# Business Travel               0
# Daily rate                    0
# Department                    0
# Distance from home            0
# Education                     0
# Education field               0
# Employee count                0
# Employee number               0
# Environment satisafaction     0
# Gender                        0
# Hourly rate                   0
# Job involvement               0
# Job level                     0
# Job role                      0
# Job satisfaction              0
# Marital status                0
# Monthly income                0
# Monthly rate                  0
# No of companies worked        0
# Over 18                       0
# Over time                     0
# Percent salary hike           0
# Performance rating            0
# Relationship satisfaction     0
# Standard hours                0
# Stock option level            0
# Total working yrs             0
# ...

# %%
#Check the structure of dataset
dataset.dtypes
# Out:
# Age                            int64
# Attrition                     object
# Business Travel               object
# Daily rate                     int64
# Department                    object
# Distance from home             int64
# Education                      int64
# Education field               object
# Employee count                 int64
# Employee number                int64
# Environment satisafaction      int64
# Gender                        object
# Hourly rate                    int64
# Job involvement                int64
# Job level                      int64
# Job role                      object
# Job satisfaction               int64
# Marital status                object
# Monthly income                 int64
# Monthly rate                   int64
# No of companies worked         int64
# Over 18                       object
# Over time                     object
# Percent salary hike            int64
# Performance rating             int64
# ...

# %%
#Columns of dataset
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'Business Travel', 'Daily rate', 'Department',
#        'Distance from home', 'Education', 'Education field', 'Employee count',
#        'Employee number', 'Environment satisafaction', 'Gender', 'Hourly rate',
#        'Job involvement', 'Job level', 'Job role', 'Job satisfaction',
#        'Marital status', 'Monthly income', 'Monthly rate',
#        'No of companies worked', 'Over 18', 'Over time', 'Percent salary hike',
#        'Performance rating', 'Relationship satisfaction', 'Standard hours',
#        'Stock option level', 'Total working yrs', 'Travelling time last yrs',
#        'Work life balance', 'Years at company', 'Years in current role',
#        'Years since last promotion', 'Years with current manager'],
#       dtype='object')

# %%
#Check the structure of dataset
hr_data.dtypes
# Out:
# Age                            int64
# Attrition                     object
# Business Travel               object
# Daily rate                     int64
# Department                    object
# Distance from home             int64
# Education                      int64
# Education field               object
# Employee count                 int64
# Employee number                int64
# Environment satisafaction      int64
# Gender                        object
# Hourly rate                    int64
# Job involvement                int64
# Job level                      int64
# Job role                      object
# Job satisfaction               int64
# Marital status                object
# Monthly income                 int64
# Monthly rate                   int64
# No of companies worked         int64
# Over 18                       object
# Over time                     object
# Percent salary hike            int64
# Performance rating             int64
# ...

# %%
#Columns of dataset
hr_data.columns
# Out:
# Index(['Age', 'Attrition', 'Business Travel', 'Daily rate', 'Department',
#        'Distance from home', 'Education', 'Education field', 'Employee count',
#        'Employee number', 'Environment satisafaction', 'Gender', 'Hourly rate',
#        'Job involvement', 'Job level', 'Job role', 'Job satisfaction',
#        'Marital status', 'Monthly income', 'Monthly rate',
#        'No of companies worked', 'Over 18', 'Over time', 'Percent salary hike',
#        'Performance rating', 'Relationship satisfaction', 'Standard hours',
#        'Stock option level', 'Total working yrs', 'Travelling time last yrs',
#        'Work life balance', 'Years at company', 'Years in current role',
#        'Years since last promotion', 'Years with current manager'],
#       dtype='object')

# %%
hr_data_num = hr_data[['Age','Daily rate','Distance from home', 'Education','Employee number', 
                       'Environment satisafaction', 'Hourly rate',                     
                       'Job involvement', 'Job level','Job satisfaction','Monthly income', 
                        'Monthly rate', 'No of companies worked','Percent salary hike', 'Performance rating', 
                       'Relationship satisfaction', 'Stock option level',
                       'Total working yrs', 'Travelling time last yrs', 'Work life balance',
                       'Years at company', 'Years in current role', 'Years since last promotion',
                       'Years with current manager']].copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize= (7,7), dpi=100)
sns.heatmap(hr_data_num.corr())
# Out:
# <AxesSubplot:>
